# %% [markdown]
# ## Problem 12
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?
#
# Note: This program is also implemented in C++ where it is only slighly faster.

# %%
# %%timeit -n1 -r1 
val = get_div(500)
print(val)
# Out:
# 76576500
# 338 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %load_ext cython

# %%
# %%cython
# #--annotate
# cimport numpy as np
# cimport cython
#
# @cython.cdivision(True)
# cdef int count_divisors(int n):
#     cdef int count = 1
#     cdef int max_val, i
#
#     max_val = int(n**(.5)+1)
#
#     count = 0 # since it is always divisible with the number itself
#     for i in range(1, max_val):
#         if (n%i) == 0:
#             if i == n/i:
#                 count += 1
#             else:
#                 count += 2
#     return count
#
# def get_div(divisors):
#     cdef int val
#
#     cdef int triangle_val = 0
#     cdef int iteration = 0
#
#     cdef int counted_divisors = 0
#
#     while counted_divisors < 500:
#         iteration += 1
#         triangle_val += iteration
#         counted_divisors = count_divisors(triangle_val)
#
#     return(triangle_val)
